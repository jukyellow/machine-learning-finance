# %%
#https://datascienceschool.net/02%20mathematics/01.01%20%EA%B7%B8%EB%A6%AC%EC%8A%A4%20%EB%AC%B8%EC%9E%90.html

# %%
#1. 수학기호

# %% [markdown]
# ![그리스문자.jpg](data:image/jpeg;base64,...)

# %%
# 수학 기호 입력(jupyter)
# $$ \alpha = \beta

# %% [markdown]
# $$ \alpha = \beta  $$

# %%
#2. 수열과 집합의 합과 곱

#수열(sequence)은 N개 숫자 또는 변수가 순서대로 나열된 것이다 
#ex) 1,2,3,4
#ex) x1, x2, x3 ...

#집합은 순서가 중요하지 않은 숫자들은 집합(set)으로 표시한다.
#ex) {1,2,3,4}
#ex) {x1, x2, x3, x4...}
#1~N까지 표현: X1:N or {Xi}N

# %%
# Tex 수식 사용법: https://en.wikipedia.org/wiki/Help:Displaying_a_formula#Formatting_using_TeX

# \begin{align}
# \sum_{k=1}^N k^2
# \end{align}

# %% [markdown]
# \begin{align}
# \sum_{k=1}^N k^2
# \end{align}

# %%
# 수열의 합

# \begin{align}
# \sum_{i=1}^N x_i = x_1 + x_2 + \ldots + x_N \tag{1.2.12}
# \end{align}

# %% [markdown]
# \begin{align}
# \sum_{i=1}^N x_i = x_1 + x_2 + \ldots + x_N \tag{1.2.12}
# \end{align}

# %%
# 수열의 곱

# \begin{align}
# \prod_{i=1}^N x_i = x_1 \cdot x_2 \cdot \ldots \cdot x_N \tag{1.2.13}
# \end{align}

# %% [markdown]
# \begin{align}
# \prod_{i=1}^N x_i = x_1 \cdot x_2 \cdot \ldots \cdot x_N \tag{1.2.13}
# \end{align}
